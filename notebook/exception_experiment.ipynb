# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### __file__ in .py file automatically gets the name of the file

# %%
import sys
import traceback ## This module provides utilities for extracting, formatting, 
## and printing stack traces of Python programs.

# %%
from logger.custom_logger import CustomLogger

logger=CustomLogger().get_logger("exception_experiment")

# %%
class DocumentPortalException(Exception):
    def __init__(self,error_message,error_details:sys):
        print(error_details.exc_info())
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info())) 
    
    def __str__(self):
        return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Message: {self.error_message}
        Traceback:
        {self.traceback_str}
        """
    
if __name__ == "__main__":
    try:
        # Simulate an error
        a = 1 / 0
        print(a)
    except Exception as e:
        app_exc=DocumentPortalException(e,sys)
        logger.error(app_exc)
        raise app_exc
# Out:
# (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x10f6c5180>)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 21
#      19 try:
#      20     # Simulate an error
# ---> 21     a = 1 / 0
#      22     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[7], line 26
#      24 app_exc=DocumentPortalException(e,sys)
#      25 logger.error(app_exc)
# ---> 26 raise app_exc
#
# DocumentPortalException:
#         Error in [/var/folders/_8/mq34yrbj1hz747klc8_wlnvr0000gn/T/ipykernel_35171/1384446983.py] at line [21]
#         Message: division by zero
#         Traceback:
#         Traceback (most recent call last):
#   File "/var/folders/_8/mq34yrbj1hz747klc8_wlnvr0000gn/T/ipykernel_35171/1384446983.py", line 21, in <module>
#     a = 1 / 0
# ZeroDivisionError: division by zero

# %% [markdown]
# 1. log this error(file, cloud config, command prompt) (it will keep the record of the error and will not stop the execution of the code)
# 2. raise the exception(it will stop the execution of the code)
